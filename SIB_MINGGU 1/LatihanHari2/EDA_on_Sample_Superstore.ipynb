# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('SampleSuperstore.csv')

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9988        30605  South       Technology       Phones  206.1000         5
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9988      0.00   55.6470
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
#
# [9993 rows x 13 columns]

# %%
data.describe(include='all')  # ringkasan statistik dari data
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9993      9993           9993           9993        9993
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5190           9993            915        2000
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
#          Postal Code Region         Category Sub-Category         Sales  \
# count    9993.000000   9993             9993         9993   9993.000000
# unique           NaN      4                3           17           NaN
# top              NaN   West  Office Supplies      Binders           NaN
# freq             NaN   3202             6025         1523           NaN
# mean    55186.627539    NaN              NaN          NaN    229.856670
# std     32063.103801    NaN              NaN          NaN    623.276273
# min      1040.000000    NaN              NaN          NaN      0.444000
# 25%     23223.000000    NaN              NaN          NaN     17.280000
# 50%     56301.000000    NaN              NaN          NaN     54.480000
# 75%     90008.000000    NaN              NaN          NaN    209.940000
# max     99301.000000    NaN              NaN          NaN  22638.480000
#
#            Quantity     Discount       Profit
# count   9993.000000  9993.000000  9993.000000
# unique          NaN          NaN          NaN
# top             NaN          NaN          NaN
# freq            NaN          NaN          NaN
# mean       3.789753     0.156218    28.652464
# std        2.225149     0.206456   234.271411
# min        1.000000     0.000000 -6599.978000
# 25%        2.000000     0.000000     1.728000
# 50%        3.000000     0.200000     8.662000
# 75%        5.000000     0.200000    29.364000
# max       14.000000     0.800000  8399.976000

# %%
data.hist(bins=10, figsize=(18,10)) #membuat histogram dari semua kolom numerik
# Out:
# array([[<Axes: title={'center': 'Postal Code'}>,
#         <Axes: title={'center': 'Sales'}>],
#        [<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Discount'}>],
#        [<Axes: title={'center': 'Profit'}>, <Axes: >]], dtype=object)

# %%
numeric_data = data.select_dtypes(include=[np.number]) #Memilih hanya kolom-kolom numerik dari data
plt.figure(figsize=(4,4)) #Mengatur ukuran gambar/plot sebesar 4x4
sns.heatmap(numeric_data.corr(), annot=True) #Membuat heatmap untuk menampilkan korelasi
# Out:
# <Axes: >

# %% [markdown]
# ## [1] Analysis based on Ship Mode

# %%
# Membuat plot pasangan (pairplot) untuk semua kombinasi kolom numerik dalam data
sns.pairplot(data, hue='Ship Mode')

# %%
#Membuat count plot (bar plot) yang menunjukkan jumlah pengamatan (frekuensi) untuk setiap kategori dalam kolom Ship Mode
sns.countplot(x='Ship Mode', data=data, palette='tab10')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
#Mengelompokkan data berdasarkan kolom Ship Mode
#Menghitung rata-rata dari kolom-kolom numerik Sales, Profit, dan Discount
data_shipmode = data.groupby(['Ship Mode'])[['Sales', 'Profit', 'Discount']].mean()
data_shipmode
# Out:
#                      Sales     Profit  Discount
# Ship Mode
# First Class     228.497024  31.839948  0.164610
# Same Day        236.396179  29.266591  0.152394
# Second Class    236.085602  29.513214  0.138966
# Standard Class  227.583067  27.494770  0.160023

# %%
colors_4 = ['magenta','yellow','orange','red']
colors_3 = ['green', 'blue','cyan']

# %%
#Membuat plot pie (diagram lingkaran) untuk setiap kolom dalam data_shipmode yaitu Sales, Profit, dan Discount
data_shipmode.plot.pie(subplots=True, figsize=(20,10), labels=data_shipmode.index, autopct='%1.1f%%', explode=(0.01,0.01,0.01,0.01), colors=colors_4)
plt.show()

# %%
#Melihat profit dan penjualan bervariasi untuk setiap kategori pengiriman.
#Mengidentifikasi kategori dengan profit tertinggi dan terendah, serta penjualan terkait dengan profit tersebut
data_shipmode.sort_values('Profit')[['Profit','Sales']].plot(kind='bar', figsize=(10,7))
# Out:
# <Axes: xlabel='Ship Mode'>

# %%
data_shipmode.sum(axis=0) #Menghitung jumlah total dari setiap kolom dalam data
# Out:
# Sales       928.561871
# Profit      118.114523
# Discount      0.615993
# dtype: float64

# %%
#menormalisasi atau menskalakan nilai Sales dan Profit
#Membuat kolom baru Sales% dalam dataframe data_shipmode.
#Mengisi kolom ini dengan nilai Sales dibagi dengan 9.285
data_shipmode['Sales%'] = data_shipmode['Sales']/9.285

#Membuat kolom baru Profit% dalam dataframe data_shipmode.
#Mengisi kolom ini dengan nilai Profit dibagi dengan 1.181
data_shipmode['Profit%'] = data_shipmode['Profit']/1.181

# %%
#Mengurutkan data data_shipmode berdasarkan kolom Profit% dalam urutan menaik.
data_shipmode.sort_values('Profit%')
# Out:
#                      Sales     Profit  Discount     Sales%    Profit%
# Ship Mode
# Standard Class  227.583067  27.494770  0.160023  24.510831  23.280923
# Same Day        236.396179  29.266591  0.152394  25.460008  24.781195
# Second Class    236.085602  29.513214  0.138966  25.426559  24.990020
# First Class     228.497024  31.839948  0.164610  24.609265  26.960159

# %% [markdown]
# ## Sales
# ### Lowest sales: Standard Class(24.51%)
# ### Highest sales: Same Day(25.46%)
#
# ## Profit
# ### Lowest profit: Standard Class(23.28%)
# ### Highest profit: First class(26.96%)
#
# #### Though there is very little differences between the classes, still, maximum and minimum can be ascertained on seeing these analysis.

# %% [markdown]
# ## [2] Analysis based on segment

# %%
#Membuat plot pasangan (pairplot) untuk semua kombinasi kolom numerik dalam data
sns.pairplot(data, hue='Segment')

# %%
#Membuat count plot (bar plot) yang menunjukkan jumlah frekuensi untuk setiap kategori dalam kolom Segment
sns.countplot(x='Segment', data=data, palette='tab10')
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %%
#Mengelompokkan data dan menghitung rata - rata
data_segment = data.groupby(['Segment'])[['Sales', 'Profit', 'Discount']].mean()

# %%
#Membuat diagram lingkaran
data_segment.plot.pie(subplots=True, figsize=(20,10), labels=data_segment.index, autopct='%1.1f%%', colors=colors_3)
# Out:
# array([<Axes: ylabel='Sales'>, <Axes: ylabel='Profit'>,
#        <Axes: ylabel='Discount'>], dtype=object)

# %%
#Memvisualisasikan nilai Profit dan Sales per kategori, diurutkan berdasarkan nilai Profit
data_segment.sort_values('Profit')[['Profit','Sales']].plot(kind='bar')
# Out:
# <Axes: xlabel='Segment'>

# %%
data_segment.sum(axis=0)
# Out:
# Sales       698.525242
# Profit       90.103127
# Discount      0.463528
# dtype: float64

# %%
data_segment['Sales%'] = data_segment['Sales']/6.985
data_segment['Profit%'] = data_segment['Profit']/0.9011

# %%
data_segment.sort_values('Profit')
# Out:
#                   Sales     Profit  Discount     Sales%    Profit%
# Segment
# Consumer     223.729901  25.827796  0.158171  32.030050  28.662519
# Corporate    233.823300  30.456667  0.158228  33.475061  33.799431
# Home Office  240.972041  33.818664  0.147128  34.498503  37.530423

# %% [markdown]
# ## Sales
# ### Lowest sales: Consumer(32.03%)
# ### Highest sales: Home Office(34.50%)
#
# ## Profit
# ### Lowest profit: Consumer(28.67%)
# ### Highest profit: Home Office(37.53%)
#
#
# #### Though there is very little differences between the classes, still, maximum and minimum can be ascertained on seeing these analysis. The corporates are on the second position for both sales an profits with Home office leading the drive in the best way for the company

# %% [markdown]
# ## [3] Analysis based on State

# %%
#Menampilkan distribusi frekuensi dari nilai-nilai dalam kolom State
plt.figure(figsize=(18,10))
sns.countplot(data['State'])
plt.xticks(rotation=90)
# Out:
# (array([   0.,  250.,  500.,  750., 1000., 1250., 1500., 1750., 2000.,
#         2250.]),
#  [Text(0.0, 0, '0'),
#   Text(250.0, 0, '250'),
#   Text(500.0, 0, '500'),
#   Text(750.0, 0, '750'),
#   Text(1000.0, 0, '1000'),
#   Text(1250.0, 0, '1250'),
#   Text(1500.0, 0, '1500'),
#   Text(1750.0, 0, '1750'),
#   Text(2000.0, 0, '2000'),
#   Text(2250.0, 0, '2250')])

# %%
data_state = data.groupby(['State'])[['Sales','Profit','Discount']].mean()

# %%
data_state1 = data_state.sort_values('Profit')

# %%
data_state2 = data_state.sort_values('Sales')

# %%
data_state2['Sales'].plot(kind='bar', figsize=(15,7))
# Out:
# <Axes: xlabel='State'>

# %%
data_state1['Profit'].plot(kind='bar', figsize=(15,7))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# ### Rather than creating a new DF and spending more memory, I came up with another simple solution

# %%
data_state.sort_values('Profit')['Profit'].plot(kind='bar', figsize=(15,7))

# Same way can be done for Sales as well.
# Out:
# <Axes: xlabel='State'>

# %%
# Sorted by Profits
data_state.sort_values('Profit')[['Profit','Sales']].plot(kind='bar', figsize=(18,8))
# Out:
# <Axes: xlabel='State'>

# %%
# Sorted by Sales
data_state.sort_values('Sales')[['Profit','Sales']].plot(kind='bar', figsize=(18,8))
# Out:
# <Axes: xlabel='State'>

# %%
data_state.sum(axis=0)
# Out:
# Sales       13545.400821
# Profit       2648.326892
# Discount        4.076661
# dtype: float64

# %%
data_state['Sales%'] = data_state['Sales']/135.454
data_state['Profit%'] = data_state['Profit']/26.483

# %%
data_state.sort_values('Profit%')
# Out:
#                             Sales      Profit  Discount     Sales%   Profit%
# State
# Ohio                   166.861697  -36.186304  0.324947   1.231870 -1.366397
# Colorado               176.418231  -35.867351  0.316484   1.302422 -1.354354
# North Carolina         223.305880  -30.083985  0.283534   1.648574 -1.135973
# Tennessee              167.551219  -29.189583  0.291257   1.236960 -1.102201
# Pennsylvania           198.487077  -26.507598  0.328620   1.465347 -1.000929
# Texas                  172.779742  -26.121174  0.370193   1.275560 -0.986337
# Illinois               162.939230  -25.625787  0.390041   1.202912 -0.967632
# Arizona                157.508933  -15.303235  0.303571   1.162822 -0.577851
# Oregon                 140.573790   -9.600569  0.288710   1.037797 -0.362518
# Florida                233.612815   -8.875461  0.299347   1.724665 -0.335138
# New Mexico             129.284378   31.273408  0.059459   0.954452  1.180886
# North Dakota           131.415714   32.878529  0.000000   0.970187  1.241496
# South Dakota           109.630000   32.902358  0.000000   0.809352  1.242395
# Kansas                 121.429583   34.851813  0.000000   0.896464  1.316007
# California             228.722236   38.154220  0.072800   1.688560  1.440706
# Idaho                  208.689810   39.367767  0.085714   1.540669  1.486530
# Iowa                   152.658667   39.460397  0.000000   1.127015  1.490027
# South Carolina         201.945476   42.120395  0.000000   1.490879  1.590469
# Connecticut            163.223866   42.823071  0.007317   1.205013  1.617002
# West Virginia          302.456000   46.480400  0.075000   2.232906  1.755103
# Utah                   211.699170   48.047802  0.060377   1.562886  1.814288
# Massachusetts          212.106919   50.262975  0.015556   1.565896  1.897934
# Louisiana              219.453095   52.288150  0.000000   1.620130  1.974404
# Nebraska               196.445526   53.607742  0.000000   1.450275  2.024232
# Maine                  158.816250   56.810775  0.000000   1.172474  2.145179
# Mississippi            203.232830   59.867475  0.000000   1.500383  2.260600
# New Hampshire          270.093481   63.203807  0.011111   1.993987  2.386580
# New York               275.599531   65.637011  0.055319   2.034636  2.478458
# Washington             273.994605   66.013146  0.064032   2.022787  2.492661
# Arkansas               194.635500   66.811452  0.000000   1.436912  2.522805
# Maryland               225.766886   66.963608  0.005714   1.666742  2.528551
# Oklahoma               298.233182   73.544788  0.000000   2.201730  2.777057
# New Jersey             275.110092   75.176260  0.004615   2.031022  2.838661
# Wisconsin              291.951000   76.380004  0.000000   2.155352  2.884114
# Kentucky               263.250000   80.573357  0.000000   1.943464  3.042456
# Virginia               315.342500   83.026564  0.000000   2.328041  3.135089
# Nevada                 428.951333   85.045279  0.061538   3.166768  3.211316
# Georgia                266.825217   88.315453  0.000000   1.969859  3.334798
# Alabama                319.846557   94.865989  0.000000   2.361293  3.582147
# Michigan               299.096525   95.934069  0.007059   2.208104  3.622477
# Missouri               336.441667   97.518341  0.000000   2.483808  3.682300
# Wyoming               1603.136000  100.196000  0.200000  11.835280  3.783408
# Delaware               285.948635  103.930988  0.006250   2.111039  3.924442
# District of Columbia   286.502000  105.958930  0.000000   2.115124  4.001017
# Minnesota              335.541011  121.608847  0.000000   2.477158  4.591959
# Montana                372.623467  122.221900  0.066667   2.750923  4.615108
# Indiana                359.431946  123.375411  0.000000   2.653535  4.658664
# Rhode Island           404.070643  130.100523  0.021429   2.983084  4.912605
# Vermont                811.760909  204.088936  0.000000   5.992890  7.706413

# %% [markdown]
# ## Sales
# ### Lowest sale: South Dakota(0.81%)
# ### Highest sale: Wyoming(11.84%)
#
# #### The company should focus on improving their sales in South dakota, kansas, new mexico, north dakota, oregon and few more states whose share in sales is miniscule

# %% [markdown]
# ## Profit
# ### Lowest profit: Ohio(-1.4%)
# ### Highest profit: Vermont(7.7%)
#
# #### The company must ascertain reasons why 10 states are leading to a loss with Ohio leading the charts. Either the faults must be corrected or considering the present situation, if the company isn't able to come to the break-even point, the operations must be discontinued.

# %% [markdown]
# ## [4] Analysis based on Region

# %%
sns.countplot(data['Region'], palette='tab10')
# Out:
# <Axes: xlabel='count', ylabel='Region'>

# %%
data_region2 = data.groupby(['Region'])[['Sales','Profit']].mean()

# %%
data_region2
# Out:
#               Sales     Profit
# Region
# Central  215.772661  17.092709
# East     238.336110  32.135808
# South    241.803645  28.857673
# West     226.488028  33.836821

# %%
data_region2.plot.pie(subplots=True, figsize=(15,7), autopct='%1.1f%%', label=data_region2.index.values, colors=colors_4)
# Out:
# array([<Axes: ylabel='Sales'>, <Axes: ylabel='Profit'>], dtype=object)

# %%
data_region2.sum(axis=0)
# Out:
# Sales     922.400443
# Profit    111.923010
# dtype: float64

# %%
data_region2['Sales%'] = data_region2['Sales']/9.224
data_region2['Profit%'] = data_region2['Profit']/1.119

# %%
data_region2.sort_values('Profit')
# Out:
#               Sales     Profit     Sales%    Profit%
# Region
# Central  215.772661  17.092709  23.392526  15.274986
# South    241.803645  28.857673  26.214619  25.788805
# East     238.336110  32.135808  25.838694  28.718327
# West     226.488028  33.836821  24.554209  30.238446

# %% [markdown]
# ## Sales
# ### Lowest sales: Central(23.40%)
# ### Highest sales: South(26.21%)
# #### The sales seem fine in all the regions since the variation range is less, however steps can still be taken to improve the sales in Central zone.
#
#
# ## Profit
# ### Lowest profit: Central(15.27%)
# ### Highest profit: West(30.25%)
# #### The profits have to be looked at since the West zone is giving almost double the profit as compared to the central one, so the company will have to take steps to analyze the shortcoming in terms of both sales and profits for the central region

# %% [markdown]
# ## [5] Analysis of Sub Category

# %%
plt.figure(figsize=(15,7))
sns.countplot(data['Sub-Category'])
plt.xticks(rotation=90)
# Out:
# (array([   0.,  200.,  400.,  600.,  800., 1000., 1200., 1400., 1600.]),
#  [Text(0.0, 0, '0'),
#   Text(200.0, 0, '200'),
#   Text(400.0, 0, '400'),
#   Text(600.0, 0, '600'),
#   Text(800.0, 0, '800'),
#   Text(1000.0, 0, '1000'),
#   Text(1200.0, 0, '1200'),
#   Text(1400.0, 0, '1400'),
#   Text(1600.0, 0, '1600')])

# %%
data_subcat = data.groupby(['Sub-Category'])[['Sales','Profit']].mean()

# %% [markdown]
# ## Sales for sub categories

# %%
plt.figure(figsize=(15,18))
plt.pie(data_subcat['Sales'], labels = data_subcat.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## Profits for sub categories

# %%
data_subcat.sort_values('Profit')[['Profit','Sales']].plot(kind='bar', figsize=(15,10))
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
data_subcat.sum(axis=0)
# Out:
# Sales     7291.484388
# Profit    1095.148131
# dtype: float64

# %%
data_subcat['Sales%'] = data_subcat['Sales']/72.915
data_subcat['Profit%'] = data_subcat['Profit']/10.952

# %%
data_subcat.sort_values('Sales')
# Out:
#                     Sales      Profit     Sales%    Profit%
# Sub-Category
# Fasteners       13.936774    4.375660   0.191137   0.399531
# Art             34.068834    8.200737   0.467240   0.748789
# Labels          34.303055   15.236962   0.470453   1.391249
# Paper           57.284092   24.856620   0.785628   2.269596
# Envelopes       64.867724   27.418019   0.889635   2.503471
# Furnishings     95.825668   13.645918   1.314211   1.245975
# Binders        133.560560   19.843574   1.831730   1.811868
# Accessories    215.974604   54.111788   2.962005   4.940813
# Appliances     230.729034   38.849586   3.164356   3.547259
# Supplies       245.650200   -6.258418   3.368994  -0.571441
# Storage        264.590553   25.152277   3.628753   2.296592
# Phones         371.211534   50.073938   5.091017   4.572127
# Bookcases      503.859633  -15.230509   6.910233  -1.390660
# Chairs         532.332420   43.095894   7.300726   3.934979
# Tables         648.794771  -55.565771   8.897960  -5.073573
# Machines      1645.553313   29.432669  22.568104   2.687424
# Copiers       2198.941618  817.909190  30.157603  74.681263

# %% [markdown]
# ## Sales
# ### Lowest sales: Fasteners(0.2%)
# ### Highest sales: Copiers(30.2%)
#
# ## Profit
# ### Lowest profit: Tables(-55.6%)
# ### Highest profit: Copiers(74.7%)
#
# #### Looking at the statistical figures, the company must have the main function in copiers since the sales and profits are heavily influenced by copiers.
# #### The company must discontinue the sales of tables since it is contributing to a heavy loss and steps could be taken to improve profits for other sub categories

# %% [markdown]
# ## Thank You for Reading!
